# %%
import warnings
warnings.filterwarnings('ignore')

import nltk
nltk.download('punkt')

import torch
import spacy
from sklearn.metrics.pairwise import cosine_similarity
from nltk.tokenize import word_tokenize
from nltk.util import ngrams
from transformers import BertTokenizer, BertModel
from sklearn.metrics.pairwise import cosine_similarity
# Out:
# [nltk_data] Downloading package punkt to /usr/share/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
standard_phrases = [
    "Optimal performance",
    "Utilise resources",
    "Enhance productivity",
    "Conduct an analysis",
    "Maintain a high standard",
    "Implement best practices",
    "Ensure compliance",
    "Streamline operations",
    "Foster innovation",
    "Drive growth",
    "Leverage synergies",
    "Demonstrate leadership",
    "Exercise due diligence",
    "Maximize stakeholder value",
    "Prioritise tasks",
    "Facilitate collaboration",
    "Monitor performance metrics",
    "Execute strategies",
    "Gauge effectiveness",
    "Champion change",
]


sample_text = "In today's meeting, we discussed a variety of issues affecting our department. " \
              "The weather was unusually sunny, a pleasant backdrop to our serious discussions. " \
              "We came to the consensus that we need to do better in terms of performance. " \
              "Sally brought doughnuts, which lightened the mood. " \
              "It's important to make good use of what we have at our disposal. " \
              "During the coffee break, we talked about the upcoming company picnic. " \
              "We should aim to be more efficient and look for ways to be more creative in our daily tasks. " \
              "Growth is essential for our future, but equally important is building strong " \
              "relationships with our team members. As a reminder, the annual staff survey " \
              "is due next Friday. Lastly, we agreed that we must take time to look over " \
              "our plans carefully and consider all angles before moving forward. On a side note, " \
              "David mentioned that his cat is recovering well from surgery."

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
nlp = spacy.load('en_core_web_sm')
model = BertModel.from_pretrained('bert-base-uncased').to(device)
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# %%
doc = nlp(sample_text)
sentences = [sent.text for sent in doc.sents]

# %%
sentences
# Out:
# ["In today's meeting, we discussed a variety of issues affecting our department.",
#  'The weather was unusually sunny, a pleasant backdrop to our serious discussions.',
#  'We came to the consensus that we need to do better in terms of performance.',
#  'Sally brought doughnuts, which lightened the mood.',
#  "It's important to make good use of what we have at our disposal.",
#  'During the coffee break, we talked about the upcoming company picnic.',
#  'We should aim to be more efficient and look for ways to be more creative in our daily tasks.',
#  'Growth is essential for our future, but equally important is building strong relationships with our team members.',
#  'As a reminder, the annual staff survey is due next Friday.',
#  'Lastly, we agreed that we must take time to look over our plans carefully and consider all angles before moving forward.',
#  'On a side note, David mentioned that his cat is recovering well from surgery.']

# %%
sample_phrases = []

for sentence in sentences:
    
    doc = nlp(sentence)
    tokens = [token.text for token in doc]
    
    for window_size in range(2, 11):
        phrases = [' '.join(tokens[i:i+window_size]) for i in range(0, len(tokens) - window_size + 1)]
        
        sample_phrases.extend(phrases)

# %%
cosine_similarity_threshold = 0.7

# Step 1: Compute the embeddings for all phrases in both lists
def get_embeddings(phrases_list):
    embeddings = []
    for phrase in phrases_list:
        inputs = tokenizer(phrase, return_tensors='pt', max_length=512, truncation=True)
        inputs = {name: tensor.to(device) for name, tensor in inputs.items()}  # Move inputs to the correct device
        with torch.no_grad():
            output = model(**inputs)
        embeddings.append(output.last_hidden_state.mean(dim=1))
    return embeddings

standard_phrases_embeddings = get_embeddings(standard_phrases)
sample_phrases_embeddings = get_embeddings(sample_phrases)

# Step 2: Calculate the cosine similarity for each pair of phrases
for i, sample_embedding in enumerate(sample_phrases_embeddings):
    for j, standard_embedding in enumerate(standard_phrases_embeddings):
        
        # Calculate cosine similarity
        cosine_sim = cosine_similarity(sample_embedding.cpu().numpy(), standard_embedding.cpu().numpy())[0][0]
        
        # Step 3: If cosine similarity is above the threshold, print the phrases and their similarity score
        if cosine_sim > cosine_similarity_threshold:
            print(f"Sample phrase: '{sample_phrases[i]}'")
            print(f"Standard phrase: '{standard_phrases[j]}'")
            print(f"Cosine similarity score: {cosine_sim:.4f}")
            print("-" * 80)
# Out:
# Sample phrase: 'meeting ,'
# Standard phrase: 'Optimal performance'
# Cosine similarity score: 0.7131
# --------------------------------------------------------------------------------
# Sample phrase: 'meeting ,'
# Standard phrase: 'Foster innovation'
# Cosine similarity score: 0.7033
# --------------------------------------------------------------------------------
# Sample phrase: 'discussed a'
# Standard phrase: 'Optimal performance'
# Cosine similarity score: 0.7128
# --------------------------------------------------------------------------------
# Sample phrase: 'issues affecting'
# Standard phrase: 'Optimal performance'
# Cosine similarity score: 0.7313
# --------------------------------------------------------------------------------
# Sample phrase: 'issues affecting'
# Standard phrase: 'Foster innovation'
# Cosine similarity score: 0.7565
# --------------------------------------------------------------------------------
# Sample phrase: 'issues affecting'
# Standard phrase: 'Drive growth'
# Cosine similarity score: 0.7116
# --------------------------------------------------------------------------------
# Sample phrase: 'issues affecting'
# Standard phrase: 'Facilitate collaboration'
# Cosine similarity score: 0.7036
# --------------------------------------------------------------------------------
# Sample phrase: 'affecting our'
# Standard phrase: 'Foster innovation'
# Cosine similarity score: 0.7230
# --------------------------------------------------------------------------------
# Sample phrase: 'affecting our'
# Standard phrase: 'Drive growth'
# Cosine similarity score: 0.7153
# --------------------------------------------------------------------------------
# Sample phrase: 'department .'
# Standard phrase: 'Optimal performance'
# Cosine similarity score: 0.7149
# --------------------------------------------------------------------------------
# Sample phrase: 'variety of issues'
# Standard phrase: 'Optimal performance'
# Cosine similarity score: 0.7206
# --------------------------------------------------------------------------------
# Sample phrase: 'variety of issues'
# Standard phrase: 'Foster innovation'
# Cosine similarity score: 0.7284
# --------------------------------------------------------------------------------
# Sample phrase: 'issues affecting our'
# Standard phrase: 'Foster innovation'
# Cosine similarity score: 0.7168
# --------------------------------------------------------------------------------
# Sample phrase: 'variety of issues affecting'
# Standard phrase: 'Implement best practices'
# Cosine similarity score: 0.7086
# --------------------------------------------------------------------------------
# Sample phrase: 'variety of issues affecting'
# Standard phrase: 'Foster innovation'
# Cosine similarity score: 0.7003
# --------------------------------------------------------------------------------
# Sample phrase: 'pleasant backdrop'
# Standard phrase: 'Optimal performance'
# Cosine similarity score: 0.7311
# --------------------------------------------------------------------------------
# Sample phrase: 'pleasant backdrop'
# Standard phrase: 'Drive growth'
# Cosine similarity score: 0.7012
# --------------------------------------------------------------------------------
# Sample phrase: 'pleasant backdrop'
# Standard phrase: 'Gauge effectiveness'
# Cosine similarity score: 0.7275
# --------------------------------------------------------------------------------
# Sample phrase: 'backdrop to'
# Standard phrase: 'Optimal performance'
# Cosine similarity score: 0.7111
# --------------------------------------------------------------------------------
# Sample phrase: 'serious discussions'
# Standard phrase: 'Optimal performance'
# Cosine similarity score: 0.7429
# --------------------------------------------------------------------------------
# Sample phrase: 'serious discussions'
# Standard phrase: 'Conduct an analysis'
# Cosine similarity score: 0.7200
# --------------------------------------------------------------------------------
# Sample phrase: 'serious discussions'
# Standard phrase: 'Foster innovation'
# Cosine similarity score: 0.7382
# --------------------------------------------------------------------------------
# Sample phrase: 'serious discussions'
# Standard phrase: 'Drive growth'
# Cosine similarity score: 0.7041
# --------------------------------------------------------------------------------
# Sample phrase: 'serious discussions'
# Standard phrase: 'Facilitate collaboration'
# Cosine similarity score: 0.7086
# --------------------------------------------------------------------------------
# Sample phrase: 'serious discussions'
# Standard phrase: 'Gauge effectiveness'
# Cosine similarity score: 0.7010
# --------------------------------------------------------------------------------
# Sample phrase: 'discussions .'
# Standard phrase: 'Optimal performance'
# Cosine similarity score: 0.7122
# --------------------------------------------------------------------------------
# Sample phrase: 'discussions .'
# Standard phrase: 'Foster innovation'
# Cosine similarity score: 0.7017
# --------------------------------------------------------------------------------
# Sample phrase: 'serious discussions .'
# Standard phrase: 'Conduct an analysis'
# Cosine similarity score: 0.7016
# --------------------------------------------------------------------------------
# Sample phrase: 'do better'
# Standard phrase: 'Drive growth'
# Cosine similarity score: 0.7023
# --------------------------------------------------------------------------------
# Sample phrase: 'do better'
# Standard phrase: 'Execute strategies'
# Cosine similarity score: 0.7363
# --------------------------------------------------------------------------------
# Sample phrase: 'terms of'
# Standard phrase: 'Optimal performance'
# Cosine similarity score: 0.7620
# --------------------------------------------------------------------------------
# Sample phrase: 'terms of'
# Standard phrase: 'Gauge effectiveness'
# Cosine similarity score: 0.7142
# --------------------------------------------------------------------------------
# Sample phrase: 'of performance'
# Standard phrase: 'Demonstrate leadership'
# Cosine similarity score: 0.7188
# --------------------------------------------------------------------------------
# Sample phrase: 'performance .'
# Standard phrase: 'Optimal performance'
# Cosine similarity score: 0.7117
# --------------------------------------------------------------------------------
# Sample phrase: 'performance .'
# Standard phrase: 'Execute strategies'
# Cosine similarity score: 0.7036
# --------------------------------------------------------------------------------
# Sample phrase: 'performance .'
# Standard phrase: 'Gauge effectiveness'
# Cosine similarity score: 0.7139
# --------------------------------------------------------------------------------
# Sample phrase: 'to do better'
# Standard phrase: 'Foster innovation'
# Cosine similarity score: 0.7174
# --------------------------------------------------------------------------------
# Sample phrase: 'to do better'
# Standard phrase: 'Drive growth'
# Cosine similarity score: 0.7353
# --------------------------------------------------------------------------------
# Sample phrase: 'do better in'
# Standard phrase: 'Drive growth'
# Cosine similarity score: 0.7114
# --------------------------------------------------------------------------------
# Sample phrase: 'terms of performance'
# Standard phrase: 'Optimal performance'
# Cosine similarity score: 0.7611
# --------------------------------------------------------------------------------
# Sample phrase: 'terms of performance'
# Standard phrase: 'Foster innovation'
# Cosine similarity score: 0.7008
# --------------------------------------------------------------------------------
# Sample phrase: 'terms of performance'
# Standard phrase: 'Monitor performance metrics'
# Cosine similarity score: 0.7063
# --------------------------------------------------------------------------------
# Sample phrase: 'of performance .'
# Standard phrase: 'Demonstrate leadership'
# Cosine similarity score: 0.7131
# --------------------------------------------------------------------------------
# Sample phrase: 'of performance .'
# Standard phrase: 'Gauge effectiveness'
# Cosine similarity score: 0.7063
# --------------------------------------------------------------------------------
# Sample phrase: 'consensus that we need'
# Standard phrase: 'Drive growth'
# Cosine similarity score: 0.7029
# --------------------------------------------------------------------------------
# Sample phrase: 'terms of performance .'
# Standard phrase: 'Monitor performance metrics'
# Cosine similarity score: 0.7418
# --------------------------------------------------------------------------------
# Sample phrase: 'terms of performance .'
# Standard phrase: 'Gauge effectiveness'
# Cosine similarity score: 0.7227
# --------------------------------------------------------------------------------
# Sample phrase: 'do better in terms of'
# Standard phrase: 'Implement best practices'
# Cosine similarity score: 0.7063
# --------------------------------------------------------------------------------
# Sample phrase: 'better in terms of performance'
# Standard phrase: 'Monitor performance metrics'
# Cosine similarity score: 0.7180
# --------------------------------------------------------------------------------
# Sample phrase: 'do better in terms of performance'
# Standard phrase: 'Implement best practices'
# Cosine similarity score: 0.7155
# --------------------------------------------------------------------------------
# Sample phrase: 'do better in terms of performance'
# Standard phrase: 'Monitor performance metrics'
# Cosine similarity score: 0.7330
# --------------------------------------------------------------------------------
# Sample phrase: 'better in terms of performance .'
# Standard phrase: 'Monitor performance metrics'
# Cosine similarity score: 0.7195
# --------------------------------------------------------------------------------
# Sample phrase: 'to do better in terms of performance'
# Standard phrase: 'Monitor performance metrics'
# Cosine similarity score: 0.7003
# --------------------------------------------------------------------------------
# Sample phrase: 'do better in terms of performance .'
# Standard phrase: 'Implement best practices'
# Cosine similarity score: 0.7047
# --------------------------------------------------------------------------------
# Sample phrase: 'do better in terms of performance .'
# Standard phrase: 'Monitor performance metrics'
# Cosine similarity score: 0.7253
# --------------------------------------------------------------------------------
# Sample phrase: 'need to do better in terms of performance'
# Standard phrase: 'Implement best practices'
# Cosine similarity score: 0.7138
# --------------------------------------------------------------------------------
# Sample phrase: 'need to do better in terms of performance'
# Standard phrase: 'Maximize stakeholder value'
# Cosine similarity score: 0.7007
# --------------------------------------------------------------------------------
# Sample phrase: 'need to do better in terms of performance'
# Standard phrase: 'Monitor performance metrics'
# Cosine similarity score: 0.7419
# --------------------------------------------------------------------------------
# Sample phrase: 'need to do better in terms of performance .'
# Standard phrase: 'Monitor performance metrics'
# Cosine similarity score: 0.7076
# --------------------------------------------------------------------------------
# Sample phrase: 'the mood'
# Standard phrase: 'Gauge effectiveness'
# Cosine similarity score: 0.7189
# --------------------------------------------------------------------------------
# Sample phrase: 'important to'
# Standard phrase: 'Gauge effectiveness'
# Cosine similarity score: 0.7068
# --------------------------------------------------------------------------------
# Sample phrase: 'to make'
# Standard phrase: 'Foster innovation'
# Cosine similarity score: 0.7120
# --------------------------------------------------------------------------------
# Sample phrase: 'to make'
# Standard phrase: 'Drive growth'
# Cosine similarity score: 0.7061
# --------------------------------------------------------------------------------
# Sample phrase: 'make good'
# Standard phrase: 'Drive growth'
# Cosine similarity score: 0.7046
# --------------------------------------------------------------------------------
# Sample phrase: 'good use'
# Standard phrase: 'Drive growth'
# Cosine similarity score: 0.7062
# --------------------------------------------------------------------------------
# Sample phrase: 'good use'
# Standard phrase: 'Gauge effectiveness'
# Cosine similarity score: 0.7108
# --------------------------------------------------------------------------------
# Sample phrase: 'use of'
# Standard phrase: 'Optimal performance'
# Cosine similarity score: 0.7915
# --------------------------------------------------------------------------------
# Sample phrase: 'use of'
# Standard phrase: 'Conduct an analysis'
# Cosine similarity score: 0.7132
# --------------------------------------------------------------------------------
# Sample phrase: 'use of'
# Standard phrase: 'Ensure compliance'
# Cosine similarity score: 0.7193
# --------------------------------------------------------------------------------
# Sample phrase: 'use of'
# Standard phrase: 'Foster innovation'
# Cosine similarity score: 0.7264
# --------------------------------------------------------------------------------
# Sample phrase: 'use of'
# Standard phrase: 'Drive growth'
# Cosine similarity score: 0.7334
# --------------------------------------------------------------------------------
# Sample phrase: 'use of'
# Standard phrase: 'Prioritise tasks'
# Cosine similarity score: 0.7090
# --------------------------------------------------------------------------------
# Sample phrase: 'use of'
# Standard phrase: 'Gauge effectiveness'
# Cosine similarity score: 0.7689
# --------------------------------------------------------------------------------
# Sample phrase: 'have at'
# Standard phrase: 'Optimal performance'
# Cosine similarity score: 0.7204
# --------------------------------------------------------------------------------
# Sample phrase: 'to make good'
# Standard phrase: 'Drive growth'
# Cosine similarity score: 0.7181
# --------------------------------------------------------------------------------
# Sample phrase: 'good use of'
# Standard phrase: 'Drive growth'
# Cosine similarity score: 0.7092
# --------------------------------------------------------------------------------
# Sample phrase: 'good use of'
# Standard phrase: 'Gauge effectiveness'
# Cosine similarity score: 0.7201
# --------------------------------------------------------------------------------
# Sample phrase: 'use of what'
# Standard phrase: 'Drive growth'
# Cosine similarity score: 0.7232
# --------------------------------------------------------------------------------
# Sample phrase: 'use of what'
# Standard phrase: 'Execute strategies'
# Cosine similarity score: 0.7005
# --------------------------------------------------------------------------------
# Sample phrase: 'use of what'
# Standard phrase: 'Gauge effectiveness'
# Cosine similarity score: 0.7352
# --------------------------------------------------------------------------------
# Sample phrase: 'to make good use'
# Standard phrase: 'Implement best practices'
# Cosine similarity score: 0.7036
# --------------------------------------------------------------------------------
# Sample phrase: 'to make good use'
# Standard phrase: 'Drive growth'
# Cosine similarity score: 0.7008
# --------------------------------------------------------------------------------
# Sample phrase: 'good use of what'
# Standard phrase: 'Gauge effectiveness'
# Cosine similarity score: 0.7002
# --------------------------------------------------------------------------------
# Sample phrase: 'important to make good use of'
# Standard phrase: 'Maintain a high standard'
# Cosine similarity score: 0.7154
# --------------------------------------------------------------------------------
# Sample phrase: 'break ,'
# Standard phrase: 'Foster innovation'
# Cosine similarity score: 0.7057
# --------------------------------------------------------------------------------
# Sample phrase: 'break ,'
# Standard phrase: 'Drive growth'
# Cosine similarity score: 0.7091
# --------------------------------------------------------------------------------
# Sample phrase: 'talked about'
# Standard phrase: 'Optimal performance'
# Cosine similarity score: 0.7015
# --------------------------------------------------------------------------------
# Sample phrase: 'talked about'
# Standard phrase: 'Foster innovation'
# Cosine similarity score: 0.7019
# --------------------------------------------------------------------------------
# Sample phrase: 'company picnic'
# Standard phrase: 'Gauge effectiveness'
# Cosine similarity score: 0.7041
# --------------------------------------------------------------------------------
# Sample phrase: 'should aim'
# Standard phrase: 'Execute strategies'
# Cosine similarity score: 0.7312
# --------------------------------------------------------------------------------
# Sample phrase: 'aim to'
# Standard phrase: 'Drive growth'
# Cosine similarity score: 0.7085
# --------------------------------------------------------------------------------
# Sample phrase: 'aim to'
# Standard phrase: 'Demonstrate leadership'
# Cosine similarity score: 0.7107
# --------------------------------------------------------------------------------
# Sample phrase: 'aim to'
# Standard phrase: 'Execute strategies'
# Cosine similarity score: 0.7770
# --------------------------------------------------------------------------------
# Sample phrase: 'more efficient'
# Standard phrase: 'Optimal performance'
# Cosine similarity score: 0.7705
# --------------------------------------------------------------------------------
# Sample phrase: 'more efficient'
# Standard phrase: 'Enhance productivity'
# Cosine similarity score: 0.7035
# --------------------------------------------------------------------------------
# Sample phrase: 'more efficient'
# Standard phrase: 'Foster innovation'
# Cosine similarity score: 0.7122
# --------------------------------------------------------------------------------
# Sample phrase: 'more efficient'
# Standard phrase: 'Drive growth'
# Cosine similarity score: 0.7590
# --------------------------------------------------------------------------------
# Sample phrase: 'more efficient'
# Standard phrase: 'Gauge effectiveness'
# Cosine similarity score: 0.7324
# --------------------------------------------------------------------------------
# Sample phrase: 'efficient and'
# Standard phrase: 'Enhance productivity'
# Cosine similarity score: 0.7218
# --------------------------------------------------------------------------------
# Sample phrase: 'efficient and'
# Standard phrase: 'Drive growth'
# Cosine similarity score: 0.7314
# --------------------------------------------------------------------------------
# Sample phrase: 'efficient and'
# Standard phrase: 'Execute strategies'
# Cosine similarity score: 0.7159
# --------------------------------------------------------------------------------
# Sample phrase: 'efficient and'
# Standard phrase: 'Gauge effectiveness'
# Cosine similarity score: 0.7013
# --------------------------------------------------------------------------------
# Sample phrase: 'more creative'
# Standard phrase: 'Optimal performance'
# Cosine similarity score: 0.7166
# --------------------------------------------------------------------------------
# Sample phrase: 'more creative'
# Standard phrase: 'Enhance productivity'
# Cosine similarity score: 0.7151
# --------------------------------------------------------------------------------
# Sample phrase: 'more creative'
# Standard phrase: 'Foster innovation'
# Cosine similarity score: 0.7577
# --------------------------------------------------------------------------------
# Sample phrase: 'more creative'
# Standard phrase: 'Drive growth'
# Cosine similarity score: 0.7817
# --------------------------------------------------------------------------------
# Sample phrase: 'more creative'
# Standard phrase: 'Execute strategies'
# Cosine similarity score: 0.7147
# --------------------------------------------------------------------------------
# Sample phrase: 'more creative'
# Standard phrase: 'Gauge effectiveness'
# Cosine similarity score: 0.7182
# --------------------------------------------------------------------------------
# Sample phrase: 'creative in'
# Standard phrase: 'Foster innovation'
# Cosine similarity score: 0.7320
# --------------------------------------------------------------------------------
# Sample phrase: 'creative in'
# Standard phrase: 'Drive growth'
# Cosine similarity score: 0.7090
# --------------------------------------------------------------------------------
# Sample phrase: 'creative in'
# Standard phrase: 'Gauge effectiveness'
# Cosine similarity score: 0.7069
# --------------------------------------------------------------------------------
# Sample phrase: 'daily tasks'
# Standard phrase: 'Optimal performance'
# Cosine similarity score: 0.7122
# --------------------------------------------------------------------------------
# Sample phrase: 'daily tasks'
# Standard phrase: 'Prioritise tasks'
# Cosine similarity score: 0.7001
# --------------------------------------------------------------------------------
# Sample phrase: 'tasks .'
# Standard phrase: 'Conduct an analysis'
# Cosine similarity score: 0.7195
# --------------------------------------------------------------------------------
# Sample phrase: 'tasks .'
# Standard phrase: 'Execute strategies'
# Cosine similarity score: 0.7791
# --------------------------------------------------------------------------------
# Sample phrase: 'tasks .'
# Standard phrase: 'Gauge effectiveness'
# Cosine similarity score: 0.7266
# --------------------------------------------------------------------------------
# Sample phrase: 'should aim to'
# Standard phrase: 'Execute strategies'
# Cosine similarity score: 0.7295
# --------------------------------------------------------------------------------
# Sample phrase: 'aim to be'
# Standard phrase: 'Foster innovation'
# Cosine similarity score: 0.7061
# --------------------------------------------------------------------------------
# Sample phrase: 'aim to be'
# Standard phrase: 'Demonstrate leadership'
# Cosine similarity score: 0.7018
# --------------------------------------------------------------------------------
# Sample phrase: 'be more efficient'
# Standard phrase: 'Optimal performance'
# Cosine similarity score: 0.7608
# --------------------------------------------------------------------------------
# Sample phrase: 'be more efficient'
# Standard phrase: 'Enhance productivity'
# Cosine similarity score: 0.7402
# --------------------------------------------------------------------------------
# Sample phrase: 'be more efficient'
# Standard phrase: 'Conduct an analysis'
# Cosine similarity score: 0.7017
# --------------------------------------------------------------------------------
# Sample phrase: 'be more efficient'
# Standard phrase: 'Implement best practices'
# Cosine similarity score: 0.7317
# --------------------------------------------------------------------------------
# Sample phrase: 'be more efficient'
# Standard phrase: 'Ensure compliance'
# Cosine similarity score: 0.7212
# --------------------------------------------------------------------------------
# Sample phrase: 'be more efficient'
# Standard phrase: 'Foster innovation'
# Cosine similarity score: 0.7351
# --------------------------------------------------------------------------------
# Sample phrase: 'be more efficient'
# Standard phrase: 'Drive growth'
# Cosine similarity score: 0.7719
# --------------------------------------------------------------------------------
# Sample phrase: 'be more efficient'
# Standard phrase: 'Monitor performance metrics'
# Cosine similarity score: 0.7036
# --------------------------------------------------------------------------------
# Sample phrase: 'be more efficient'
# Standard phrase: 'Execute strategies'
# Cosine similarity score: 0.7293
# --------------------------------------------------------------------------------
# Sample phrase: 'be more efficient'
# Standard phrase: 'Gauge effectiveness'
# Cosine similarity score: 0.7410
# --------------------------------------------------------------------------------
# Sample phrase: 'more efficient and'
# Standard phrase: 'Enhance productivity'
# Cosine similarity score: 0.7112
# --------------------------------------------------------------------------------
# Sample phrase: 'more efficient and'
# Standard phrase: 'Drive growth'
# Cosine similarity score: 0.7266
# --------------------------------------------------------------------------------
# Sample phrase: 'be more creative'
# Standard phrase: 'Enhance productivity'
# Cosine similarity score: 0.7423
# --------------------------------------------------------------------------------
# Sample phrase: 'be more creative'
# Standard phrase: 'Implement best practices'
# Cosine similarity score: 0.7564
# --------------------------------------------------------------------------------
# Sample phrase: 'be more creative'
# Standard phrase: 'Foster innovation'
# Cosine similarity score: 0.7751
# --------------------------------------------------------------------------------
# Sample phrase: 'be more creative'
# Standard phrase: 'Drive growth'
# Cosine similarity score: 0.7730
# --------------------------------------------------------------------------------
# Sample phrase: 'be more creative'
# Standard phrase: 'Demonstrate leadership'
# Cosine similarity score: 0.7118
# --------------------------------------------------------------------------------
# Sample phrase: 'be more creative'
# Standard phrase: 'Execute strategies'
# Cosine similarity score: 0.7035
# --------------------------------------------------------------------------------
# Sample phrase: 'more creative in'
# Standard phrase: 'Enhance productivity'
# Cosine similarity score: 0.7122
# --------------------------------------------------------------------------------
# Sample phrase: 'more creative in'
# Standard phrase: 'Foster innovation'
# Cosine similarity score: 0.7017
# --------------------------------------------------------------------------------
# Sample phrase: 'more creative in'
# Standard phrase: 'Drive growth'
# Cosine similarity score: 0.7496
# --------------------------------------------------------------------------------
# Sample phrase: 'more creative in'
# Standard phrase: 'Execute strategies'
# Cosine similarity score: 0.7058
# --------------------------------------------------------------------------------
# Sample phrase: 'more creative in'
# Standard phrase: 'Gauge effectiveness'
# Cosine similarity score: 0.7222
# --------------------------------------------------------------------------------
# Sample phrase: 'daily tasks .'
# Standard phrase: 'Optimal performance'
# Cosine similarity score: 0.7038
# --------------------------------------------------------------------------------
# Sample phrase: 'daily tasks .'
# Standard phrase: 'Conduct an analysis'
# Cosine similarity score: 0.7121
# --------------------------------------------------------------------------------
# Sample phrase: 'daily tasks .'
# Standard phrase: 'Demonstrate leadership'
# Cosine similarity score: 0.7059
# --------------------------------------------------------------------------------
# Sample phrase: 'daily tasks .'
# Standard phrase: 'Execute strategies'
# Cosine similarity score: 0.7127
# --------------------------------------------------------------------------------
# Sample phrase: 'daily tasks .'
# Standard phrase: 'Gauge effectiveness'
# Cosine similarity score: 0.7086
# --------------------------------------------------------------------------------
# Sample phrase: 'aim to be more'
# Standard phrase: 'Foster innovation'
# Cosine similarity score: 0.7096
# --------------------------------------------------------------------------------
# Sample phrase: 'to be more efficient'
# Standard phrase: 'Optimal performance'
# Cosine similarity score: 0.7015
# --------------------------------------------------------------------------------
# Sample phrase: 'to be more efficient'
# Standard phrase: 'Enhance productivity'
# Cosine similarity score: 0.7348
# --------------------------------------------------------------------------------
# Sample phrase: 'to be more efficient'
# Standard phrase: 'Foster innovation'
# Cosine similarity score: 0.7086
# --------------------------------------------------------------------------------
# Sample phrase: 'to be more efficient'
# Standard phrase: 'Drive growth'
# Cosine similarity score: 0.7574
# --------------------------------------------------------------------------------
# Sample phrase: 'to be more efficient'
# Standard phrase: 'Gauge effectiveness'
# Cosine similarity score: 0.7180
# --------------------------------------------------------------------------------
# Sample phrase: 'be more efficient and'
# Standard phrase: 'Enhance productivity'
# Cosine similarity score: 0.7605
# --------------------------------------------------------------------------------
# Sample phrase: 'be more efficient and'
# Standard phrase: 'Conduct an analysis'
# Cosine similarity score: 0.7096
# --------------------------------------------------------------------------------
# Sample phrase: 'be more efficient and'
# Standard phrase: 'Maintain a high standard'
# Cosine similarity score: 0.7053
# --------------------------------------------------------------------------------
# Sample phrase: 'be more efficient and'
# Standard phrase: 'Implement best practices'
# Cosine similarity score: 0.7532
# --------------------------------------------------------------------------------
# Sample phrase: 'be more efficient and'
# Standard phrase: 'Ensure compliance'
# Cosine similarity score: 0.7139
# --------------------------------------------------------------------------------
# Sample phrase: 'be more efficient and'
# Standard phrase: 'Foster innovation'
# Cosine similarity score: 0.7242
# --------------------------------------------------------------------------------
# Sample phrase: 'be more efficient and'
# Standard phrase: 'Drive growth'
# Cosine similarity score: 0.7665
# --------------------------------------------------------------------------------
# Sample phrase: 'be more efficient and'
# Standard phrase: 'Monitor performance metrics'
# Cosine similarity score: 0.7084
# --------------------------------------------------------------------------------
# Sample phrase: 'be more efficient and'
# Standard phrase: 'Execute strategies'
# Cosine similarity score: 0.7034
# --------------------------------------------------------------------------------
# Sample phrase: 'more efficient and look'
# Standard phrase: 'Drive growth'
# Cosine similarity score: 0.7140
# --------------------------------------------------------------------------------
# Sample phrase: 'more efficient and look'
# Standard phrase: 'Gauge effectiveness'
# Cosine similarity score: 0.7068
# --------------------------------------------------------------------------------
# Sample phrase: 'to be more creative'
# Standard phrase: 'Enhance productivity'
# Cosine similarity score: 0.7359
# --------------------------------------------------------------------------------
# Sample phrase: 'to be more creative'
# Standard phrase: 'Implement best practices'
# Cosine similarity score: 0.7033
# --------------------------------------------------------------------------------
# Sample phrase: 'to be more creative'
# Standard phrase: 'Foster innovation'
# Cosine similarity score: 0.7099
# --------------------------------------------------------------------------------
# Sample phrase: 'to be more creative'
# Standard phrase: 'Drive growth'
# Cosine similarity score: 0.7487
# --------------------------------------------------------------------------------
# Sample phrase: 'be more creative in'
# Standard phrase: 'Enhance productivity'
# Cosine similarity score: 0.7149
# --------------------------------------------------------------------------------
# Sample phrase: 'be more creative in'
# Standard phrase: 'Conduct an analysis'
# Cosine similarity score: 0.7006
# --------------------------------------------------------------------------------
# Sample phrase: 'be more creative in'
# Standard phrase: 'Implement best practices'
# Cosine similarity score: 0.7270
# --------------------------------------------------------------------------------
# Sample phrase: 'be more creative in'
# Standard phrase: 'Foster innovation'
# Cosine similarity score: 0.7344
# --------------------------------------------------------------------------------
# Sample phrase: 'be more creative in'
# Standard phrase: 'Drive growth'
# Cosine similarity score: 0.7561
# --------------------------------------------------------------------------------
# Sample phrase: 'be more creative in'
# Standard phrase: 'Execute strategies'
# Cosine similarity score: 0.7026
# --------------------------------------------------------------------------------
# Sample phrase: 'more creative in our'
# Standard phrase: 'Drive growth'
# Cosine similarity score: 0.7012
# --------------------------------------------------------------------------------
# Sample phrase: 'aim to be more efficient'
# Standard phrase: 'Enhance productivity'
# Cosine similarity score: 0.7524
# --------------------------------------------------------------------------------
# Sample phrase: 'aim to be more efficient'
# Standard phrase: 'Maintain a high standard'
# Cosine similarity score: 0.7040
# --------------------------------------------------------------------------------
# Sample phrase: 'aim to be more efficient'
# Standard phrase: 'Implement best practices'
# Cosine similarity score: 0.7554
# --------------------------------------------------------------------------------
# Sample phrase: 'aim to be more efficient'
# Standard phrase: 'Ensure compliance'
# Cosine similarity score: 0.7004
# --------------------------------------------------------------------------------
# Sample phrase: 'aim to be more efficient'
# Standard phrase: 'Foster innovation'
# Cosine similarity score: 0.7122
# --------------------------------------------------------------------------------
# Sample phrase: 'aim to be more efficient'
# Standard phrase: 'Drive growth'
# Cosine similarity score: 0.7380
# --------------------------------------------------------------------------------
# Sample phrase: 'aim to be more efficient'
# Standard phrase: 'Monitor performance metrics'
# Cosine similarity score: 0.7255
# --------------------------------------------------------------------------------
# Sample phrase: 'to be more efficient and'
# Standard phrase: 'Enhance productivity'
# Cosine similarity score: 0.7333
# --------------------------------------------------------------------------------
# Sample phrase: 'to be more efficient and'
# Standard phrase: 'Drive growth'
# Cosine similarity score: 0.7476
# --------------------------------------------------------------------------------
# Sample phrase: 'be more efficient and look'
# Standard phrase: 'Enhance productivity'
# Cosine similarity score: 0.7076
# --------------------------------------------------------------------------------
# Sample phrase: 'be more efficient and look'
# Standard phrase: 'Conduct an analysis'
# Cosine similarity score: 0.7090
# --------------------------------------------------------------------------------
# Sample phrase: 'be more efficient and look'
# Standard phrase: 'Implement best practices'
# Cosine similarity score: 0.7092
# --------------------------------------------------------------------------------
# Sample phrase: 'be more efficient and look'
# Standard phrase: 'Drive growth'
# Cosine similarity score: 0.7249
# --------------------------------------------------------------------------------
# Sample phrase: 'be more efficient and look'
# Standard phrase: 'Gauge effectiveness'
# Cosine similarity score: 0.7053
# --------------------------------------------------------------------------------
# Sample phrase: 'to be more creative in'
# Standard phrase: 'Enhance productivity'
# Cosine similarity score: 0.7015
# --------------------------------------------------------------------------------
# Sample phrase: 'to be more creative in'
# Standard phrase: 'Drive growth'
# Cosine similarity score: 0.7371
# --------------------------------------------------------------------------------
# Sample phrase: 'be more creative in our'
# Standard phrase: 'Implement best practices'
# Cosine similarity score: 0.7074
# --------------------------------------------------------------------------------
# Sample phrase: 'should aim to be more efficient'
# Standard phrase: 'Enhance productivity'
# Cosine similarity score: 0.7201
# --------------------------------------------------------------------------------
# Sample phrase: 'should aim to be more efficient'
# Standard phrase: 'Maintain a high standard'
# Cosine similarity score: 0.7036
# --------------------------------------------------------------------------------
# Sample phrase: 'should aim to be more efficient'
# Standard phrase: 'Implement best practices'
# Cosine similarity score: 0.7258
# --------------------------------------------------------------------------------
# Sample phrase: 'aim to be more efficient and'
# Standard phrase: 'Enhance productivity'
# Cosine similarity score: 0.7443
# --------------------------------------------------------------------------------
# Sample phrase: 'aim to be more efficient and'
# Standard phrase: 'Maintain a high standard'
# Cosine similarity score: 0.7257
# --------------------------------------------------------------------------------
# Sample phrase: 'aim to be more efficient and'
# Standard phrase: 'Implement best practices'
# Cosine similarity score: 0.7528
# --------------------------------------------------------------------------------
# Sample phrase: 'aim to be more efficient and'
# Standard phrase: 'Drive growth'
# Cosine similarity score: 0.7238
# --------------------------------------------------------------------------------
# Sample phrase: 'aim to be more efficient and'
# Standard phrase: 'Monitor performance metrics'
# Cosine similarity score: 0.7017
# --------------------------------------------------------------------------------
# Sample phrase: 'should aim to be more efficient and'
# Standard phrase: 'Enhance productivity'
# Cosine similarity score: 0.7180
# --------------------------------------------------------------------------------
# Sample phrase: 'should aim to be more efficient and'
# Standard phrase: 'Maintain a high standard'
# Cosine similarity score: 0.7229
# --------------------------------------------------------------------------------
# Sample phrase: 'should aim to be more efficient and'
# Standard phrase: 'Implement best practices'
# Cosine similarity score: 0.7258
# --------------------------------------------------------------------------------
# Sample phrase: 'aim to be more efficient and look'
# Standard phrase: 'Enhance productivity'
# Cosine similarity score: 0.7251
# --------------------------------------------------------------------------------
# Sample phrase: 'aim to be more efficient and look'
# Standard phrase: 'Implement best practices'
# Cosine similarity score: 0.7152
# --------------------------------------------------------------------------------
# Sample phrase: 'aim to be more efficient and look'
# Standard phrase: 'Drive growth'
# Cosine similarity score: 0.7019
# --------------------------------------------------------------------------------
# Sample phrase: 'aim to be more efficient and look'
# Standard phrase: 'Monitor performance metrics'
# Cosine similarity score: 0.7047
# --------------------------------------------------------------------------------
# Sample phrase: 'be more efficient and look for ways'
# Standard phrase: 'Implement best practices'
# Cosine similarity score: 0.7011
# --------------------------------------------------------------------------------
# Sample phrase: 'be more creative in our daily tasks'
# Standard phrase: 'Maintain a high standard'
# Cosine similarity score: 0.7001
# --------------------------------------------------------------------------------
# Sample phrase: 'be more creative in our daily tasks'
# Standard phrase: 'Implement best practices'
# Cosine similarity score: 0.7029
# --------------------------------------------------------------------------------
# Sample phrase: 'aim to be more efficient and look for'
# Standard phrase: 'Implement best practices'
# Cosine similarity score: 0.7040
# --------------------------------------------------------------------------------
# Sample phrase: 'aim to be more efficient and look for'
# Standard phrase: 'Monitor performance metrics'
# Cosine similarity score: 0.7010
# --------------------------------------------------------------------------------
# Sample phrase: 'be more efficient and look for ways to'
# Standard phrase: 'Implement best practices'
# Cosine similarity score: 0.7023
# --------------------------------------------------------------------------------
# Sample phrase: 'aim to be more efficient and look for ways'
# Standard phrase: 'Implement best practices'
# Cosine similarity score: 0.7185
# --------------------------------------------------------------------------------
# Sample phrase: 'should aim to be more efficient and look for ways'
# Standard phrase: 'Implement best practices'
# Cosine similarity score: 0.7074
# --------------------------------------------------------------------------------
# Sample phrase: 'aim to be more efficient and look for ways to'
# Standard phrase: 'Implement best practices'
# Cosine similarity score: 0.7184
# --------------------------------------------------------------------------------
# Sample phrase: 'Growth is'
# Standard phrase: 'Optimal performance'
# Cosine similarity score: 0.7848
# --------------------------------------------------------------------------------
# Sample phrase: 'Growth is'
# Standard phrase: 'Enhance productivity'
# Cosine similarity score: 0.7362
# --------------------------------------------------------------------------------
# Sample phrase: 'Growth is'
# Standard phrase: 'Foster innovation'
# Cosine similarity score: 0.7223
# --------------------------------------------------------------------------------
# Sample phrase: 'Growth is'
# Standard phrase: 'Drive growth'
# Cosine similarity score: 0.8203
# --------------------------------------------------------------------------------
# Sample phrase: 'Growth is'
# Standard phrase: 'Gauge effectiveness'
# Cosine similarity score: 0.7516
# --------------------------------------------------------------------------------
# Sample phrase: 'essential for'
# Standard phrase: 'Optimal performance'
# Cosine similarity score: 0.7473
# --------------------------------------------------------------------------------
# Sample phrase: 'essential for'
# Standard phrase: 'Drive growth'
# Cosine similarity score: 0.7146
# --------------------------------------------------------------------------------
# Sample phrase: 'essential for'
# Standard phrase: 'Gauge effectiveness'
# Cosine similarity score: 0.7402
# --------------------------------------------------------------------------------
# Sample phrase: 'our future'
# Standard phrase: 'Optimal performance'
# Cosine similarity score: 0.7027
# --------------------------------------------------------------------------------
# Sample phrase: 'our future'
# Standard phrase: 'Foster innovation'
# Cosine similarity score: 0.7238
# --------------------------------------------------------------------------------
# Sample phrase: 'important is'
# Standard phrase: 'Gauge effectiveness'
# Cosine similarity score: 0.7187
# --------------------------------------------------------------------------------
# Sample phrase: 'building strong'
# Standard phrase: 'Optimal performance'
# Cosine similarity score: 0.7566
# --------------------------------------------------------------------------------
# Sample phrase: 'building strong'
# Standard phrase: 'Enhance productivity'
# Cosine similarity score: 0.7030
# --------------------------------------------------------------------------------
# Sample phrase: 'building strong'
# Standard phrase: 'Foster innovation'
# Cosine similarity score: 0.7667
# --------------------------------------------------------------------------------
# Sample phrase: 'building strong'
# Standard phrase: 'Drive growth'
# Cosine similarity score: 0.8104
# --------------------------------------------------------------------------------
# Sample phrase: 'building strong'
# Standard phrase: 'Execute strategies'
# Cosine similarity score: 0.7303
# --------------------------------------------------------------------------------
# Sample phrase: 'building strong'
# Standard phrase: 'Gauge effectiveness'
# Cosine similarity score: 0.7424
# --------------------------------------------------------------------------------
# Sample phrase: 'strong relationships'
# Standard phrase: 'Optimal performance'
# Cosine similarity score: 0.7101
# --------------------------------------------------------------------------------
# Sample phrase: 'strong relationships'
# Standard phrase: 'Drive growth'
# Cosine similarity score: 0.7496
# --------------------------------------------------------------------------------
# Sample phrase: 'strong relationships'
# Standard phrase: 'Gauge effectiveness'
# Cosine similarity score: 0.7300
# --------------------------------------------------------------------------------
# Sample phrase: 'relationships with'
# Standard phrase: 'Conduct an analysis'
# Cosine similarity score: 0.7055
# --------------------------------------------------------------------------------
# Sample phrase: 'relationships with'
# Standard phrase: 'Gauge effectiveness'
# Cosine similarity score: 0.7010
# --------------------------------------------------------------------------------
# Sample phrase: 'team members'
# Standard phrase: 'Optimal performance'
# Cosine similarity score: 0.7563
# --------------------------------------------------------------------------------
# Sample phrase: 'team members'
# Standard phrase: 'Foster innovation'
# Cosine similarity score: 0.7112
# --------------------------------------------------------------------------------
# Sample phrase: 'Growth is essential'
# Standard phrase: 'Enhance productivity'
# Cosine similarity score: 0.7019
# --------------------------------------------------------------------------------
# Sample phrase: 'Growth is essential'
# Standard phrase: 'Drive growth'
# Cosine similarity score: 0.7577
# --------------------------------------------------------------------------------
# Sample phrase: 'essential for our'
# Standard phrase: 'Foster innovation'
# Cosine similarity score: 0.7258
# --------------------------------------------------------------------------------
# Sample phrase: 'essential for our'
# Standard phrase: 'Drive growth'
# Cosine similarity score: 0.7191
# --------------------------------------------------------------------------------
# Sample phrase: 'is building strong'
# Standard phrase: 'Drive growth'
# Cosine similarity score: 0.7017
# --------------------------------------------------------------------------------
# Sample phrase: 'building strong relationships'
# Standard phrase: 'Enhance productivity'
# Cosine similarity score: 0.7646
# --------------------------------------------------------------------------------
# Sample phrase: 'building strong relationships'
# Standard phrase: 'Conduct an analysis'
# Cosine similarity score: 0.7028
# --------------------------------------------------------------------------------
# Sample phrase: 'building strong relationships'
# Standard phrase: 'Implement best practices'
# Cosine similarity score: 0.7656
# --------------------------------------------------------------------------------
# Sample phrase: 'building strong relationships'
# Standard phrase: 'Foster innovation'
# Cosine similarity score: 0.7265
# --------------------------------------------------------------------------------
# Sample phrase: 'building strong relationships'
# Standard phrase: 'Drive growth'
# Cosine similarity score: 0.7689
# --------------------------------------------------------------------------------
# Sample phrase: 'building strong relationships'
# Standard phrase: 'Demonstrate leadership'
# Cosine similarity score: 0.7145
# --------------------------------------------------------------------------------
# Sample phrase: 'building strong relationships'
# Standard phrase: 'Facilitate collaboration'
# Cosine similarity score: 0.7172
# --------------------------------------------------------------------------------
# Sample phrase: 'building strong relationships'
# Standard phrase: 'Gauge effectiveness'
# Cosine similarity score: 0.7102
# --------------------------------------------------------------------------------
# Sample phrase: 'strong relationships with'
# Standard phrase: 'Conduct an analysis'
# Cosine similarity score: 0.7046
# --------------------------------------------------------------------------------
# Sample phrase: 'strong relationships with'
# Standard phrase: 'Implement best practices'
# Cosine similarity score: 0.7065
# ...
# --------------------------------------------------------------------------------
# Sample phrase: 'building strong relationships with'
# Standard phrase: 'Drive growth'
# Cosine similarity score: 0.7505
# --------------------------------------------------------------------------------
# Sample phrase: 'building strong relationships with'
# Standard phrase: 'Facilitate collaboration'
# Cosine similarity score: 0.7166
# --------------------------------------------------------------------------------
# Sample phrase: 'strong relationships with our'
# Standard phrase: 'Implement best practices'
# Cosine similarity score: 0.7061
# --------------------------------------------------------------------------------
# Sample phrase: 'strong relationships with our'
# Standard phrase: 'Drive growth'
# Cosine similarity score: 0.7147
# --------------------------------------------------------------------------------
# Sample phrase: 'Growth is essential for our'
# Standard phrase: 'Enhance productivity'
# Cosine similarity score: 0.7047
# --------------------------------------------------------------------------------
# Sample phrase: 'important is building strong relationships'
# Standard phrase: 'Enhance productivity'
# Cosine similarity score: 0.7076
# --------------------------------------------------------------------------------
# Sample phrase: 'important is building strong relationships'
# Standard phrase: 'Implement best practices'
# Cosine similarity score: 0.7184
# --------------------------------------------------------------------------------
# Sample phrase: 'important is building strong relationships'
# Standard phrase: 'Drive growth'
# Cosine similarity score: 0.7029
# --------------------------------------------------------------------------------
# Sample phrase: 'important is building strong relationships'
# Standard phrase: 'Gauge effectiveness'
# Cosine similarity score: 0.7043
# --------------------------------------------------------------------------------
# Sample phrase: 'building strong relationships with our'
# Standard phrase: 'Enhance productivity'
# Cosine similarity score: 0.7237
# --------------------------------------------------------------------------------
# Sample phrase: 'building strong relationships with our'
# Standard phrase: 'Implement best practices'
# Cosine similarity score: 0.7627
# --------------------------------------------------------------------------------
# Sample phrase: 'building strong relationships with our'
# Standard phrase: 'Foster innovation'
# Cosine similarity score: 0.7016
# --------------------------------------------------------------------------------
# Sample phrase: 'building strong relationships with our'
# Standard phrase: 'Drive growth'
# Cosine similarity score: 0.7228
# --------------------------------------------------------------------------------
# Sample phrase: 'important is building strong relationships with'
# Standard phrase: 'Implement best practices'
# Cosine similarity score: 0.7332
# --------------------------------------------------------------------------------
# Sample phrase: 'building strong relationships with our team'
# Standard phrase: 'Maintain a high standard'
# Cosine similarity score: 0.7014
# --------------------------------------------------------------------------------
# Sample phrase: 'building strong relationships with our team'
# Standard phrase: 'Implement best practices'
# Cosine similarity score: 0.7236
# --------------------------------------------------------------------------------
# Sample phrase: 'strong relationships with our team members'
# Standard phrase: 'Maintain a high standard'
# Cosine similarity score: 0.7017
# --------------------------------------------------------------------------------
# Sample phrase: 'strong relationships with our team members'
# Standard phrase: 'Implement best practices'
# Cosine similarity score: 0.7064
# --------------------------------------------------------------------------------
# Sample phrase: 'equally important is building strong relationships with'
# Standard phrase: 'Implement best practices'
# Cosine similarity score: 0.7129
# --------------------------------------------------------------------------------
# Sample phrase: 'important is building strong relationships with our'
# Standard phrase: 'Implement best practices'
# Cosine similarity score: 0.7146
# --------------------------------------------------------------------------------
# Sample phrase: 'building strong relationships with our team members'
# Standard phrase: 'Implement best practices'
# Cosine similarity score: 0.7248
# --------------------------------------------------------------------------------
# Sample phrase: 'equally important is building strong relationships with our'
# Standard phrase: 'Implement best practices'
# Cosine similarity score: 0.7011
# --------------------------------------------------------------------------------
# Sample phrase: 'a reminder'
# Standard phrase: 'Optimal performance'
# Cosine similarity score: 0.7047
# --------------------------------------------------------------------------------
# Sample phrase: 'staff survey'
# Standard phrase: 'Conduct an analysis'
# Cosine similarity score: 0.7012
# --------------------------------------------------------------------------------
# Sample phrase: 'staff survey'
# Standard phrase: 'Streamline operations'
# Cosine similarity score: 0.7053
# --------------------------------------------------------------------------------
# Sample phrase: 'staff survey'
# Standard phrase: 'Drive growth'
# Cosine similarity score: 0.7046
# --------------------------------------------------------------------------------
# Sample phrase: 'staff survey'
# Standard phrase: 'Gauge effectiveness'
# Cosine similarity score: 0.7627
# --------------------------------------------------------------------------------
# Sample phrase: 'survey is'
# Standard phrase: 'Optimal performance'
# Cosine similarity score: 0.7472
# --------------------------------------------------------------------------------
# Sample phrase: 'survey is'
# Standard phrase: 'Gauge effectiveness'
# Cosine similarity score: 0.7444
# --------------------------------------------------------------------------------
# Sample phrase: 'annual staff survey'
# Standard phrase: 'Gauge effectiveness'
# Cosine similarity score: 0.7233
# --------------------------------------------------------------------------------
# Sample phrase: 'staff survey is'
# Standard phrase: 'Conduct an analysis'
# Cosine similarity score: 0.7153
# --------------------------------------------------------------------------------
# Sample phrase: 'staff survey is'
# Standard phrase: 'Streamline operations'
# Cosine similarity score: 0.7001
# --------------------------------------------------------------------------------
# Sample phrase: 'staff survey is'
# Standard phrase: 'Gauge effectiveness'
# Cosine similarity score: 0.7498
# --------------------------------------------------------------------------------
# Sample phrase: 'annual staff survey is'
# Standard phrase: 'Conduct an analysis'
# Cosine similarity score: 0.7028
# --------------------------------------------------------------------------------
# Sample phrase: 'take time'
# Standard phrase: 'Drive growth'
# Cosine similarity score: 0.7512
# --------------------------------------------------------------------------------
# Sample phrase: 'take time'
# Standard phrase: 'Execute strategies'
# Cosine similarity score: 0.7274
# --------------------------------------------------------------------------------
# Sample phrase: 'to look'
# Standard phrase: 'Foster innovation'
# Cosine similarity score: 0.7251
# --------------------------------------------------------------------------------
# Sample phrase: 'to look'
# Standard phrase: 'Drive growth'
# Cosine similarity score: 0.7050
# --------------------------------------------------------------------------------
# Sample phrase: 'our plans'
# Standard phrase: 'Optimal performance'
# Cosine similarity score: 0.7131
# --------------------------------------------------------------------------------
# Sample phrase: 'our plans'
# Standard phrase: 'Foster innovation'
# Cosine similarity score: 0.7078
# --------------------------------------------------------------------------------
# Sample phrase: 'plans carefully'
# Standard phrase: 'Optimal performance'
# Cosine similarity score: 0.7394
# --------------------------------------------------------------------------------
# Sample phrase: 'plans carefully'
# Standard phrase: 'Conduct an analysis'
# Cosine similarity score: 0.7623
# --------------------------------------------------------------------------------
# Sample phrase: 'plans carefully'
# Standard phrase: 'Implement best practices'
# Cosine similarity score: 0.7490
# --------------------------------------------------------------------------------
# Sample phrase: 'plans carefully'
# Standard phrase: 'Ensure compliance'
# Cosine similarity score: 0.7524
# --------------------------------------------------------------------------------
# Sample phrase: 'plans carefully'
# Standard phrase: 'Foster innovation'
# Cosine similarity score: 0.7181
# --------------------------------------------------------------------------------
# Sample phrase: 'plans carefully'
# Standard phrase: 'Drive growth'
# Cosine similarity score: 0.7686
# --------------------------------------------------------------------------------
# Sample phrase: 'plans carefully'
# Standard phrase: 'Facilitate collaboration'
# Cosine similarity score: 0.7142
# --------------------------------------------------------------------------------
# Sample phrase: 'plans carefully'
# Standard phrase: 'Execute strategies'
# Cosine similarity score: 0.7835
# --------------------------------------------------------------------------------
# Sample phrase: 'plans carefully'
# Standard phrase: 'Gauge effectiveness'
# Cosine similarity score: 0.7204
# --------------------------------------------------------------------------------
# Sample phrase: 'consider all'
# Standard phrase: 'Conduct an analysis'
# Cosine similarity score: 0.7136
# --------------------------------------------------------------------------------
# Sample phrase: 'consider all'
# Standard phrase: 'Foster innovation'
# Cosine similarity score: 0.7015
# --------------------------------------------------------------------------------
# Sample phrase: 'consider all'
# Standard phrase: 'Execute strategies'
# Cosine similarity score: 0.7066
# --------------------------------------------------------------------------------
# Sample phrase: 'all angles'
# Standard phrase: 'Optimal performance'
# Cosine similarity score: 0.7297
# --------------------------------------------------------------------------------
# Sample phrase: 'angles before'
# Standard phrase: 'Drive growth'
# Cosine similarity score: 0.7010
# --------------------------------------------------------------------------------
# Sample phrase: 'angles before'
# Standard phrase: 'Execute strategies'
# Cosine similarity score: 0.7291
# --------------------------------------------------------------------------------
# Sample phrase: 'angles before'
# Standard phrase: 'Gauge effectiveness'
# Cosine similarity score: 0.7161
# --------------------------------------------------------------------------------
# Sample phrase: 'moving forward'
# Standard phrase: 'Drive growth'
# Cosine similarity score: 0.7186
# --------------------------------------------------------------------------------
# Sample phrase: 'take time to'
# Standard phrase: 'Drive growth'
# Cosine similarity score: 0.7269
# --------------------------------------------------------------------------------
# Sample phrase: 'our plans carefully'
# Standard phrase: 'Drive growth'
# Cosine similarity score: 0.7156
# --------------------------------------------------------------------------------
# Sample phrase: 'our plans carefully'
# Standard phrase: 'Execute strategies'
# Cosine similarity score: 0.7153
# --------------------------------------------------------------------------------
# Sample phrase: 'plans carefully and'
# Standard phrase: 'Conduct an analysis'
# Cosine similarity score: 0.7222
# --------------------------------------------------------------------------------
# Sample phrase: 'plans carefully and'
# Standard phrase: 'Maintain a high standard'
# Cosine similarity score: 0.7284
# --------------------------------------------------------------------------------
# Sample phrase: 'plans carefully and'
# Standard phrase: 'Implement best practices'
# Cosine similarity score: 0.7374
# --------------------------------------------------------------------------------
# Sample phrase: 'plans carefully and'
# Standard phrase: 'Ensure compliance'
# Cosine similarity score: 0.7065
# --------------------------------------------------------------------------------
# Sample phrase: 'plans carefully and'
# Standard phrase: 'Execute strategies'
# Cosine similarity score: 0.7236
# --------------------------------------------------------------------------------
# Sample phrase: 'carefully and consider'
# Standard phrase: 'Conduct an analysis'
# Cosine similarity score: 0.7056
# --------------------------------------------------------------------------------
# Sample phrase: 'plans carefully and consider'
# Standard phrase: 'Maintain a high standard'
# Cosine similarity score: 0.7437
# --------------------------------------------------------------------------------
# Sample phrase: 'plans carefully and consider'
# Standard phrase: 'Implement best practices'
# Cosine similarity score: 0.7310
# --------------------------------------------------------------------------------
# Sample phrase: 'carefully and consider all'
# Standard phrase: 'Conduct an analysis'
# Cosine similarity score: 0.7096
# --------------------------------------------------------------------------------
# Sample phrase: 'carefully and consider all'
# Standard phrase: 'Implement best practices'
# Cosine similarity score: 0.7007
# --------------------------------------------------------------------------------
# Sample phrase: 'our plans carefully and consider'
# Standard phrase: 'Maintain a high standard'
# Cosine similarity score: 0.7180
# --------------------------------------------------------------------------------
# Sample phrase: 'our plans carefully and consider'
# Standard phrase: 'Implement best practices'
# Cosine similarity score: 0.7018
# --------------------------------------------------------------------------------
# Sample phrase: 'plans carefully and consider all'
# Standard phrase: 'Maintain a high standard'
# Cosine similarity score: 0.7406
# --------------------------------------------------------------------------------
# Sample phrase: 'plans carefully and consider all'
# Standard phrase: 'Implement best practices'
# Cosine similarity score: 0.7117
# --------------------------------------------------------------------------------
# Sample phrase: 'our plans carefully and consider all'
# Standard phrase: 'Maintain a high standard'
# Cosine similarity score: 0.7124
# --------------------------------------------------------------------------------
# Sample phrase: 'plans carefully and consider all angles'
# Standard phrase: 'Maintain a high standard'
# Cosine similarity score: 0.7329
# --------------------------------------------------------------------------------
# Sample phrase: 'plans carefully and consider all angles'
# Standard phrase: 'Implement best practices'
# Cosine similarity score: 0.7001
# --------------------------------------------------------------------------------
# Sample phrase: 'our plans carefully and consider all angles'
# Standard phrase: 'Maintain a high standard'
# Cosine similarity score: 0.7114
# --------------------------------------------------------------------------------
# Sample phrase: 'plans carefully and consider all angles before'
# Standard phrase: 'Maintain a high standard'
# Cosine similarity score: 0.7045
# --------------------------------------------------------------------------------
# Sample phrase: 'plans carefully and consider all angles before moving forward'
# Standard phrase: 'Maintain a high standard'
# Cosine similarity score: 0.7119
# --------------------------------------------------------------------------------
# Sample phrase: 'plans carefully and consider all angles before moving forward .'
# Standard phrase: 'Maintain a high standard'
# Cosine similarity score: 0.7042
# --------------------------------------------------------------------------------
